# %% [markdown]
# # Birds, dinosaurs, reptiles, and mammals (oh my)
#
# We don't have data on cerebrum size for most organisms, but we can apply machine learning to body mass and brain volume values to classify organisms into birds, dinosaurs, reptiles, and mammals.
#
# ## Import libraries and data
#
# Import the libraries you need to build a decision tree and read the bird_dino_gator.csv file into a dataframe. How many rows does the data have?

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn import neighbors 
from sklearn import datasets
from sklearn.tree import export_graphviz
import pydotplus
import graphviz
from sklearn import metrics
import matplotlib as mpl

# %%
var = pd.read_csv("bird_mammal_dino_reptile.csv")
var["Species Type"].loc[var["Species Type"]=="B"]=0
var["Species Type"].loc[var["Species Type"]=="D"]=1
var["Species Type"].loc[var["Species Type"]=="R"]=2
var["Species Type"].loc[var["Species Type"]=="M"]=3
var
# Out:
# /Users/brownscholar/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#       Species Type                Genus          Species  Brain mass (g)  \
# 0                3              Sciurus           aberti    6.850000e+00
# 1                3             Cynomops          abrasus    4.180000e-01
# 2                3            Myoprocta          acouchy    9.900000e+00
# 3                3          Rhinolophus       acuminatus    3.020000e-01
# 4                3       Lagenorhynchus           acutus    1.200000e+03
# 5                3                Canis          adustus    5.650000e+01
# 6                3               Myotis         adversus    2.545000e-01
# 7                3             Tadarida       aegyptiaca    3.930000e-01
# 8                3            Rousettus      aegyptiacus    2.600000e+00
# 9                3         Phacochoerus      aethiopicus    1.250000e+02
# 10               3          Chlorocebus         aethiops    6.610000e+01
# 11               3          Chlorocebus         aethiops    6.630000e+01
# 12               3          Chlorocebus         aethiops    3.654000e+01
# 13               3          Chlorocebus         aethiops    6.000000e+01
# 14               3          Orycteropus             afer    7.200000e+01
# 15               3          Rhinolophus          affinis    3.475000e-01
# 16               3               Ratufa          affinis    9.850000e+00
# 17               3              Coleura             afra    2.585000e-01
# 18               3         Gerbilliscus             afra    1.560000e+00
# 19               3            Loxodonta         africana    4.050000e+03
# 20               3            Loxodonta         africana    4.420000e+03
# 21               3            Loxodonta         africana    9.000000e+03
# 22               3            Loxodonta         africana    4.000000e+03
# 23               3            Loxodonta         africana    5.712000e+03
# 24               3            Loxodonta         africana    4.480000e+03
# 25               3         Phacochoerus        africanus    1.325000e+02
# 26               3            Atherurus        africanus    1.847000e+01
# 27               3            Atherurus        africanus    2.530000e+01
# 28               3           Cercocebus           agilis    9.530000e+01
# 29               3            Hylobates           agilis    7.700000e+01
# ...            ...                  ...              ...             ...
# 6545             0               Forpus  xanthopterygius    1.050000e+00
# 6546             0               Forpus  xanthopterygius    9.800000e-01
# 6547             0           Cyanocorax            yncas    2.209000e+00
# 6548             0           Cyanocorax            yncas    2.550000e+00
# 6549             0             Erpornis      zantholeuca    4.550000e-01
# 6550             0             Ficedula      zanthopygia    5.200000e-01
# 6551             0             Ficedula      zanthopygia    4.480000e-01
# 6552             0           Barnardius         zonarius    3.430000e+00
# 6553             0           Barnardius         zonarius    3.950000e+00
# 6554             0           Barnardius         zonarius    3.060000e+00
# 6555             0           Barnardius         zonarius    3.270000e+00
# 6556             0           Barnardius         zonarius    5.130000e+00
# 6557             0           Barnardius         zonarius    4.100000e+00
# 6558             0           Barnardius         zonarius    4.341000e+00
# 6559             0           Barnardius         zonarius    3.710000e+00
# 6560             0           Barnardius         zonarius    3.280000e+00
# 6561             0           Barnardius         zonarius    4.300000e+00
# 6562             0           Barnardius         zonarius    3.900000e+00
# 6563             0           Barnardius         zonarius    5.211000e+00
# 6564             1        Tyrannosaurus              sp.    4.312000e+06
# 6565             1        Tyrannosaurus              sp.    5.654000e+06
# 6566             1        Tyrannosaurus              sp.    5.000000e+06
# 6567             1        Tyrannosaurus              sp.    7.000000e+06
# 6568             1        Tyrannosaurus              sp.    5.000000e+06
# 6569             1          Gorgosaurus              sp.    1.110000e+06
# 6570             1         Nanotyrannus              sp.    2.400000e+05
# 6571             1         Nanotyrannus              sp.    2.800000e+05
# 6572             1           Allosaurus              sp.    1.400000e+05
# 6573             1  Carcharodontosaurus              sp.    5.000000e+06
# 6574             1  Carcharodontosaurus              sp.    7.000000e+06
#
#       Body mass (g)
# 0           626.500
# 1            33.300
# 2           782.000
# 3            12.100
# 4        120000.000
# 5         12000.000
# 6            11.250
# 7            17.700
# 8           130.000
# 9         65320.000
# 10         3220.000
# 11         5230.000
# 12         1370.000
# 13         1908.000
# 14        52500.000
# 15           13.500
# 16          982.500
# 17           11.500
# 18           65.000
# 19      1793300.000
# 20      3505000.000
# 21      4380000.000
# 22      5174400.000
# 23      6654000.000
# 24      2750000.000
# 25        67000.000
# 26         2685.000
# 27         3620.000
# 28         4700.000
# 29         4536.000
# ...             ...
# 6545         30.300
# 6546         21.000
# 6547         50.791
# 6548         61.400
# 6549         13.783
# 6550          8.400
# 6551          9.161
# 6552        106.000
# 6553        127.510
# 6554        107.800
# 6555        116.600
# 6556        141.400
# 6557        129.400
# 6558        131.690
# 6559         95.500
# 6560        107.400
# 6561        114.700
# 6562        106.500
# 6563        143.750
# 6564        116.050
# 6565        153.250
# 6566        141.250
# 6567        149.480
# 6568        126.910
# 6569         47.700
# 6570         41.140
# 6571         74.490
# 6572         69.520
# 6573         82.880
# 6574         97.560
#
# [6575 rows x 5 columns]

# %%
var2= var.to_numpy()
data= var2[:,0:5]
data
# Out:
# array([[3, 'Sciurus', 'aberti', 6.85, 626.5],
#        [3, 'Cynomops', 'abrasus', 0.418, 33.3],
#        [3, 'Myoprocta', 'acouchy', 9.9, 782.0],
#        ...,
#        [1, 'Allosaurus', 'sp.', 140000.0, 69.52],
#        [1, 'Carcharodontosaurus', 'sp.', 5000000.0, 82.88],
#        [1, 'Carcharodontosaurus', 'sp.', 7000000.0, 97.56]], dtype=object)

# %% [markdown]
# Convert the dataframe to a numpy array. (Note, we are not going to calculate a brain to body mass ratio here, we are just going to use these two values as our features for each species.)

# %% [markdown]
# ## Training/test data
#
# We are going to split up our dataset into training data, that we will use to train the algorithm, and test data, that we will use to see how well the algorithm performs like we did with the k-nearest neighbors algorithm. From sklearn.model_selection, import train_test_split. Divide the data into 80% training and 20% test data:

# %%
x= data[:,3:5]
y= data[:,0]
#X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.3)
from sklearn.model_selection import train_test_split  
xtr,xte,ytr,yte= train_test_split(x, y, test_size=0.2)
#print(xtr)
#print(ytr)
print(yte)
# Out:
# [0 0 0 ... 0 0 0]

# %%
type(ytr)
ytr= ytr.astype('int')
yte= yte.astype('int')

# %% [markdown]
# ## Create decision tree
#
# Create a decision tree classifier to classify the brains as birds, dinosaurs, or reptiles based on the brain to body mass ratio and cerebrum to whole brain ratio. Make sure to run your decision tree only on the training data (not the test data).

# %%
clf = tree.DecisionTreeClassifier()
fit= clf.fit(xtr,ytr)
tree.plot_tree(fit,class_names=["bird","dino","reptile","mammal"])
#graph.write_png('plstree.png')
# Out:
# [Text(190.6516134490647, 213.816, 'X[0] <= 10.228\ngini = 0.465\nsamples = 5260\nvalue = [3494, 9, 151, 1606]\nclass = bird'),
#  Text(52.64239626372286, 206.56799999999998, 'X[0] <= 0.312\ngini = 0.342\nsamples = 4327\nvalue = [3423, 0, 147, 757]\nclass = bird'),
#  Text(5.485387692893885, 199.32, 'X[0] <= 0.104\ngini = 0.565\nsamples = 296\nvalue = [22, 0, 132, 142]\nclass = mammal'),
#  Text(1.02053724518956, 192.072, 'X[0] <= 0.061\ngini = 0.114\nsamples = 115\nvalue = [0, 0, 108, 7]\nclass = reptile'),
#  Text(0.51026862259478, 184.824, 'gini = 0.0\nsamples = 96\nvalue = [0, 0, 96, 0]\nclass = reptile'),
#  Text(1.53080586778434, 184.824, 'X[1] <= 6.375\ngini = 0.465\nsamples = 19\nvalue = [0, 0, 12, 7]\nclass = reptile'),
#  Text(1.02053724518956, 177.576, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7]\nclass = mammal'),
#  Text(2.04107449037912, 177.576, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0]\nclass = reptile'),
#  Text(9.950238140598211, 192.072, 'X[1] <= 20.65\ngini = 0.411\nsamples = 181\nvalue = [22, 0, 24, 135]\nclass = mammal'),
#  Text(6.12322347113736, 184.824, 'X[0] <= 0.239\ngini = 0.244\nsamples = 155\nvalue = [22, 0, 0, 133]\nclass = mammal'),
#  Text(3.06161173556868, 177.576, 'X[0] <= 0.232\ngini = 0.044\nsamples = 89\nvalue = [2, 0, 0, 87]\nclass = mammal'),
#  Text(2.04107449037912, 170.328, 'X[0] <= 0.19\ngini = 0.024\nsamples = 82\nvalue = [1, 0, 0, 81]\nclass = mammal'),
#  Text(1.53080586778434, 163.07999999999998, 'gini = 0.0\nsamples = 56\nvalue = [0, 0, 0, 56]\nclass = mammal'),
#  Text(2.5513431129739, 163.07999999999998, 'X[0] <= 0.192\ngini = 0.074\nsamples = 26\nvalue = [1, 0, 0, 25]\nclass = mammal'),
#  Text(2.04107449037912, 155.832, 'X[1] <= 7.69\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = mammal'),
#  Text(1.53080586778434, 148.584, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(2.5513431129739, 148.584, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = mammal'),
#  Text(3.06161173556868, 155.832, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 22]\nclass = mammal'),
#  Text(4.08214898075824, 170.328, 'X[1] <= 9.137\ngini = 0.245\nsamples = 7\nvalue = [1, 0, 0, 6]\nclass = mammal'),
#  Text(3.57188035816346, 163.07999999999998, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]\nclass = mammal'),
#  Text(4.59241760335302, 163.07999999999998, 'X[1] <= 11.737\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(4.08214898075824, 155.832, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(5.1026862259478, 155.832, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(9.18483520670604, 177.576, 'X[1] <= 6.25\ngini = 0.422\nsamples = 66\nvalue = [20, 0, 0, 46]\nclass = mammal'),
#  Text(8.67456658411126, 170.328, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0, 0]\nclass = bird'),
#  Text(9.69510382930082, 170.328, 'X[1] <= 7.75\ngini = 0.293\nsamples = 56\nvalue = [10, 0, 0, 46]\nclass = mammal'),
#  Text(7.14376071632692, 163.07999999999998, 'X[1] <= 7.413\ngini = 0.494\nsamples = 9\nvalue = [4, 0, 0, 5]\nclass = mammal'),
#  Text(6.12322347113736, 155.832, 'X[1] <= 6.855\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 0, 4]\nclass = mammal'),
#  Text(5.61295484854258, 148.584, 'X[0] <= 0.286\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(5.1026862259478, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(6.12322347113736, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(6.63349209373214, 148.584, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = mammal'),
#  Text(8.16429796151648, 155.832, 'X[1] <= 7.622\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]\nclass = bird'),
#  Text(7.6540293389217, 148.584, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(8.67456658411126, 148.584, 'X[0] <= 0.255\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(8.16429796151648, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(9.18483520670604, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(12.24644694227472, 163.07999999999998, 'X[0] <= 0.277\ngini = 0.223\nsamples = 47\nvalue = [6, 0, 0, 41]\nclass = mammal'),
#  Text(11.22590969708516, 155.832, 'X[0] <= 0.241\ngini = 0.08\nsamples = 24\nvalue = [1, 0, 0, 23]\nclass = mammal'),
#  Text(10.71564107449038, 148.584, 'X[1] <= 10.675\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 0, 4]\nclass = mammal'),
#  Text(10.2053724518956, 141.336, 'X[1] <= 9.375\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(9.69510382930082, 134.088, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(10.71564107449038, 134.088, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(11.22590969708516, 141.336, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = mammal'),
#  Text(11.73617831967994, 148.584, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19]\nclass = mammal'),
#  Text(13.26698418746428, 155.832, 'X[0] <= 0.278\ngini = 0.34\nsamples = 23\nvalue = [5, 0, 0, 18]\nclass = mammal'),
#  Text(12.7567155648695, 148.584, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(13.77725281005906, 148.584, 'X[1] <= 12.925\ngini = 0.298\nsamples = 22\nvalue = [4, 0, 0, 18]\nclass = mammal'),
#  Text(12.7567155648695, 141.336, 'X[1] <= 9.65\ngini = 0.208\nsamples = 17\nvalue = [2, 0, 0, 15]\nclass = mammal'),
#  Text(12.24644694227472, 134.088, 'X[1] <= 8.57\ngini = 0.375\nsamples = 8\nvalue = [2, 0, 0, 6]\nclass = mammal'),
#  Text(11.73617831967994, 126.83999999999999, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]\nclass = mammal'),
#  Text(12.7567155648695, 126.83999999999999, 'X[1] <= 8.72\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(12.24644694227472, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(13.26698418746428, 119.592, 'X[0] <= 0.29\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(12.7567155648695, 112.344, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(13.77725281005906, 112.344, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(13.26698418746428, 134.088, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9]\nclass = mammal'),
#  Text(14.79779005524862, 141.336, 'X[1] <= 14.171\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]\nclass = mammal'),
#  Text(14.28752143265384, 134.088, 'X[1] <= 13.225\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(13.77725281005906, 126.83999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(14.79779005524862, 126.83999999999999, 'X[1] <= 13.521\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(14.28752143265384, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(15.3080586778434, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(15.3080586778434, 134.088, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(13.77725281005906, 184.824, 'X[0] <= 0.307\ngini = 0.142\nsamples = 26\nvalue = [0, 0, 24, 2]\nclass = reptile'),
#  Text(13.26698418746428, 177.576, 'X[0] <= 0.199\ngini = 0.077\nsamples = 25\nvalue = [0, 0, 24, 1]\nclass = reptile'),
#  Text(12.7567155648695, 170.328, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0]\nclass = reptile'),
#  Text(13.77725281005906, 170.328, 'X[0] <= 0.205\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 1]\nclass = reptile'),
#  Text(13.26698418746428, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(14.28752143265384, 163.07999999999998, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0]\nclass = reptile'),
#  Text(14.28752143265384, 177.576, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(99.79940483455182, 199.32, 'X[1] <= 31.486\ngini = 0.265\nsamples = 4031\nvalue = [3401, 0, 15, 615]\nclass = bird'),
#  Text(38.11467422366165, 192.072, 'X[0] <= 0.449\ngini = 0.162\nsamples = 1542\nvalue = [1405, 0, 0, 137]\nclass = bird'),
#  Text(24.620461040198137, 184.824, 'X[1] <= 14.7\ngini = 0.402\nsamples = 194\nvalue = [140, 0, 0, 54]\nclass = bird'),
#  Text(19.39020765860164, 177.576, 'X[1] <= 10.22\ngini = 0.251\nsamples = 143\nvalue = [122, 0, 0, 21]\nclass = bird'),
#  Text(16.32859592303296, 170.328, 'X[0] <= 0.357\ngini = 0.144\nsamples = 77\nvalue = [71, 0, 0, 6]\nclass = bird'),
#  Text(15.3080586778434, 163.07999999999998, 'X[1] <= 6.024\ngini = 0.415\nsamples = 17\nvalue = [12, 0, 0, 5]\nclass = bird'),
#  Text(14.79779005524862, 155.832, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = bird'),
#  Text(15.818327300438181, 155.832, 'X[0] <= 0.321\ngini = 0.494\nsamples = 9\nvalue = [4, 0, 0, 5]\nclass = mammal'),
#  Text(15.3080586778434, 148.584, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(16.32859592303296, 148.584, 'X[1] <= 7.35\ngini = 0.408\nsamples = 7\nvalue = [2, 0, 0, 5]\nclass = mammal'),
#  Text(15.818327300438181, 141.336, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(16.83886454562774, 141.336, 'X[0] <= 0.351\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]\nclass = mammal'),
#  Text(16.32859592303296, 134.088, 'X[0] <= 0.331\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(15.818327300438181, 126.83999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(16.83886454562774, 126.83999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(17.34913316822252, 134.088, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(17.34913316822252, 163.07999999999998, 'X[1] <= 8.534\ngini = 0.033\nsamples = 60\nvalue = [59, 0, 0, 1]\nclass = bird'),
#  Text(16.83886454562774, 155.832, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0, 0]\nclass = bird'),
#  Text(17.8594017908173, 155.832, 'X[1] <= 8.575\ngini = 0.1\nsamples = 19\nvalue = [18, 0, 0, 1]\nclass = bird'),
#  Text(17.34913316822252, 148.584, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(18.36967041341208, 148.584, 'gini = 0.0\nsamples = 18\nvalue = [18, 0, 0, 0]\nclass = bird'),
#  Text(22.45181939417032, 170.328, 'X[1] <= 10.75\ngini = 0.351\nsamples = 66\nvalue = [51, 0, 0, 15]\nclass = bird'),
#  Text(21.94155077157554, 163.07999999999998, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = mammal'),
#  Text(22.9620880167651, 163.07999999999998, 'X[0] <= 0.446\ngini = 0.292\nsamples = 62\nvalue = [51, 0, 0, 11]\nclass = bird'),
#  Text(20.92101352638598, 155.832, 'X[1] <= 11.604\ngini = 0.259\nsamples = 59\nvalue = [50, 0, 0, 9]\nclass = bird'),
#  Text(19.39020765860164, 148.584, 'X[1] <= 11.175\ngini = 0.388\nsamples = 19\nvalue = [14, 0, 0, 5]\nclass = bird'),
#  Text(18.87993903600686, 141.336, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0, 0]\nclass = bird'),
#  Text(19.900476281196422, 141.336, 'X[1] <= 11.275\ngini = 0.5\nsamples = 10\nvalue = [5, 0, 0, 5]\nclass = bird'),
#  Text(18.36967041341208, 134.088, 'X[0] <= 0.41\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = mammal'),
#  Text(17.8594017908173, 126.83999999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(18.87993903600686, 126.83999999999999, 'X[0] <= 0.433\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(18.36967041341208, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(19.39020765860164, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(21.43128214898076, 134.088, 'X[1] <= 11.554\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2]\nclass = bird'),
#  Text(20.92101352638598, 126.83999999999999, 'X[1] <= 11.373\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = bird'),
#  Text(20.4107449037912, 119.592, 'X[1] <= 11.325\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(19.900476281196422, 112.344, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(20.92101352638598, 112.344, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(21.43128214898076, 119.592, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(21.94155077157554, 126.83999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(22.45181939417032, 148.584, 'X[1] <= 13.31\ngini = 0.18\nsamples = 40\nvalue = [36, 0, 0, 4]\nclass = bird'),
#  Text(21.94155077157554, 141.336, 'gini = 0.0\nsamples = 21\nvalue = [21, 0, 0, 0]\nclass = bird'),
#  Text(22.9620880167651, 141.336, 'X[1] <= 13.512\ngini = 0.332\nsamples = 19\nvalue = [15, 0, 0, 4]\nclass = bird'),
#  Text(22.45181939417032, 134.088, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = mammal'),
#  Text(23.47235663935988, 134.088, 'X[0] <= 0.395\ngini = 0.117\nsamples = 16\nvalue = [15, 0, 0, 1]\nclass = bird'),
#  Text(22.9620880167651, 126.83999999999999, 'X[0] <= 0.385\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]\nclass = bird'),
#  Text(22.45181939417032, 119.592, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(23.47235663935988, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(23.98262526195466, 126.83999999999999, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]\nclass = bird'),
#  Text(25.00316250714422, 155.832, 'X[0] <= 0.448\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]\nclass = mammal'),
#  Text(24.49289388454944, 148.584, 'X[1] <= 11.855\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(23.98262526195466, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(25.00316250714422, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(25.513431129739, 148.584, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(29.85071442179463, 177.576, 'X[1] <= 18.752\ngini = 0.457\nsamples = 51\nvalue = [18, 0, 0, 33]\nclass = mammal'),
#  Text(28.0647742427129, 170.328, 'X[1] <= 15.64\ngini = 0.499\nsamples = 31\nvalue = [16, 0, 0, 15]\nclass = bird'),
#  Text(27.55450562011812, 163.07999999999998, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]\nclass = mammal'),
#  Text(28.57504286530768, 163.07999999999998, 'X[0] <= 0.401\ngini = 0.423\nsamples = 23\nvalue = [16, 0, 0, 7]\nclass = bird'),
#  Text(27.55450562011812, 155.832, 'X[1] <= 17.892\ngini = 0.5\nsamples = 12\nvalue = [6, 0, 0, 6]\nclass = bird'),
#  Text(27.044236997523342, 148.584, 'X[1] <= 16.83\ngini = 0.48\nsamples = 10\nvalue = [6, 0, 0, 4]\nclass = bird'),
#  Text(26.02369975233378, 141.336, 'X[1] <= 16.47\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]\nclass = mammal'),
#  Text(25.513431129739, 134.088, 'X[0] <= 0.352\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(25.00316250714422, 126.83999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(26.02369975233378, 126.83999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(26.53396837492856, 134.088, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(28.0647742427129, 141.336, 'X[1] <= 17.642\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = bird'),
#  Text(27.55450562011812, 134.088, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(28.57504286530768, 134.088, 'X[1] <= 17.743\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(28.0647742427129, 126.83999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(29.08531148790246, 126.83999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(28.0647742427129, 148.584, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(29.59558011049724, 155.832, 'X[0] <= 0.428\ngini = 0.165\nsamples = 11\nvalue = [10, 0, 0, 1]\nclass = bird'),
#  Text(29.08531148790246, 148.584, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = bird'),
#  Text(30.10584873309202, 148.584, 'X[0] <= 0.434\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(29.59558011049724, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(30.6161173556868, 141.336, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(31.636654600876362, 170.328, 'X[1] <= 28.425\ngini = 0.18\nsamples = 20\nvalue = [2, 0, 0, 18]\nclass = mammal'),
#  Text(31.12638597828158, 163.07999999999998, 'X[0] <= 0.433\ngini = 0.1\nsamples = 19\nvalue = [1, 0, 0, 18]\nclass = mammal'),
#  Text(30.6161173556868, 155.832, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15]\nclass = mammal'),
#  Text(31.636654600876362, 155.832, 'X[0] <= 0.434\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = mammal'),
#  Text(31.12638597828158, 148.584, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(32.14692322347114, 148.584, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = mammal'),
#  Text(32.14692322347114, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(51.608887407125174, 184.824, 'X[0] <= 0.74\ngini = 0.116\nsamples = 1348\nvalue = [1265, 0, 0, 83]\nclass = bird'),
#  Text(41.98554010287674, 177.576, 'X[1] <= 21.286\ngini = 0.161\nsamples = 802\nvalue = [731, 0, 0, 71]\nclass = bird'),
#  Text(34.95340064774243, 170.328, 'X[1] <= 12.187\ngini = 0.085\nsamples = 626\nvalue = [598, 0, 0, 28]\nclass = bird'),
#  Text(34.44313202514765, 163.07999999999998, 'gini = 0.0\nsamples = 231\nvalue = [231, 0, 0, 0]\nclass = bird'),
#  Text(35.46366927033721, 163.07999999999998, 'X[0] <= 0.612\ngini = 0.132\nsamples = 395\nvalue = [367, 0, 0, 28]\nclass = bird'),
#  Text(34.95340064774243, 155.832, 'X[1] <= 12.21\ngini = 0.189\nsamples = 265\nvalue = [237, 0, 0, 28]\nclass = bird'),
#  Text(33.1674604686607, 148.584, 'X[0] <= 0.463\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(32.65719184606592, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(33.67772909125548, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(36.73934082682416, 148.584, 'X[1] <= 13.53\ngini = 0.184\nsamples = 263\nvalue = [236, 0, 0, 27]\nclass = bird'),
#  Text(34.69826633644504, 141.336, 'X[0] <= 0.579\ngini = 0.069\nsamples = 56\nvalue = [54, 0, 0, 2]\nclass = bird'),
#  Text(33.67772909125548, 134.088, 'X[0] <= 0.469\ngini = 0.038\nsamples = 51\nvalue = [50, 0, 0, 1]\nclass = bird'),
#  Text(33.1674604686607, 126.83999999999999, 'X[0] <= 0.468\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 0, 1]\nclass = bird'),
#  Text(32.65719184606592, 119.592, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = bird'),
#  Text(33.67772909125548, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(34.18799771385026, 126.83999999999999, 'gini = 0.0\nsamples = 42\nvalue = [42, 0, 0, 0]\nclass = bird'),
#  Text(35.7188035816346, 134.088, 'X[0] <= 0.592\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = bird'),
#  Text(35.208534959039824, 126.83999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(36.22907220422938, 126.83999999999999, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = bird'),
#  Text(38.78041531720328, 141.336, 'X[1] <= 13.57\ngini = 0.212\nsamples = 207\nvalue = [182, 0, 0, 25]\nclass = bird'),
#  Text(38.2701466946085, 134.088, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(39.29068393979806, 134.088, 'X[0] <= 0.609\ngini = 0.206\nsamples = 206\nvalue = [182, 0, 0, 24]\nclass = bird'),
#  Text(37.24960944941894, 126.83999999999999, 'X[1] <= 18.521\ngini = 0.2\nsamples = 204\nvalue = [181, 0, 0, 23]\nclass = bird'),
#  Text(34.69826633644504, 119.592, 'X[1] <= 18.436\ngini = 0.227\nsamples = 161\nvalue = [140, 0, 0, 21]\nclass = bird'),
#  Text(34.18799771385026, 112.344, 'X[1] <= 15.82\ngini = 0.219\nsamples = 160\nvalue = [140, 0, 0, 20]\nclass = bird'),
#  Text(31.89178891217375, 105.09599999999999, 'X[0] <= 0.597\ngini = 0.145\nsamples = 76\nvalue = [70, 0, 0, 6]\nclass = bird'),
#  Text(30.6161173556868, 97.848, 'X[0] <= 0.524\ngini = 0.084\nsamples = 68\nvalue = [65, 0, 0, 3]\nclass = bird'),
#  Text(30.10584873309202, 90.6, 'X[0] <= 0.522\ngini = 0.127\nsamples = 44\nvalue = [41, 0, 0, 3]\nclass = bird'),
#  Text(29.08531148790246, 83.352, 'X[1] <= 14.778\ngini = 0.091\nsamples = 42\nvalue = [40, 0, 0, 2]\nclass = bird'),
#  Text(28.57504286530768, 76.10399999999998, 'X[1] <= 14.734\ngini = 0.198\nsamples = 18\nvalue = [16, 0, 0, 2]\nclass = bird'),
#  Text(28.0647742427129, 68.856, 'X[0] <= 0.51\ngini = 0.111\nsamples = 17\nvalue = [16, 0, 0, 1]\nclass = bird'),
#  Text(27.55450562011812, 61.608000000000004, 'gini = 0.0\nsamples = 15\nvalue = [15, 0, 0, 0]\nclass = bird'),
#  Text(28.57504286530768, 61.608000000000004, 'X[1] <= 13.99\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(28.0647742427129, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(29.08531148790246, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(29.08531148790246, 68.856, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(29.59558011049724, 76.10399999999998, 'gini = 0.0\nsamples = 24\nvalue = [24, 0, 0, 0]\nclass = bird'),
#  Text(31.12638597828158, 83.352, 'X[1] <= 14.959\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(30.6161173556868, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(31.636654600876362, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(31.12638597828158, 90.6, 'gini = 0.0\nsamples = 24\nvalue = [24, 0, 0, 0]\nclass = bird'),
#  Text(33.1674604686607, 97.848, 'X[1] <= 14.45\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 0, 3]\nclass = bird'),
#  Text(32.65719184606592, 90.6, 'X[0] <= 0.604\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = mammal'),
#  Text(32.14692322347114, 83.352, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = mammal'),
#  Text(33.1674604686607, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(33.67772909125548, 90.6, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = bird'),
#  Text(36.48420651552677, 105.09599999999999, 'X[1] <= 16.028\ngini = 0.278\nsamples = 84\nvalue = [70, 0, 0, 14]\nclass = bird'),
#  Text(35.208534959039824, 97.848, 'X[1] <= 15.982\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = mammal'),
#  Text(34.69826633644504, 90.6, 'X[1] <= 15.902\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(34.18799771385026, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(35.208534959039824, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(35.7188035816346, 90.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(37.75987807201372, 97.848, 'X[0] <= 0.562\ngini = 0.237\nsamples = 80\nvalue = [69, 0, 0, 11]\nclass = bird'),
#  Text(36.73934082682416, 90.6, 'X[0] <= 0.558\ngini = 0.32\nsamples = 50\nvalue = [40, 0, 0, 10]\nclass = bird'),
#  Text(36.22907220422938, 83.352, 'X[1] <= 16.389\ngini = 0.3\nsamples = 49\nvalue = [40, 0, 0, 9]\nclass = bird'),
#  Text(35.7188035816346, 76.10399999999998, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0, 0]\nclass = bird'),
#  Text(36.73934082682416, 76.10399999999998, 'X[1] <= 16.48\ngini = 0.355\nsamples = 39\nvalue = [30, 0, 0, 9]\nclass = bird'),
#  Text(36.22907220422938, 68.856, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(37.24960944941894, 68.856, 'X[1] <= 17.08\ngini = 0.307\nsamples = 37\nvalue = [30, 0, 0, 7]\nclass = bird'),
#  Text(36.22907220422938, 61.608000000000004, 'X[0] <= 0.455\ngini = 0.124\nsamples = 15\nvalue = [14, 0, 0, 1]\nclass = bird'),
#  Text(35.7188035816346, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(36.73934082682416, 54.359999999999985, 'gini = 0.0\nsamples = 14\nvalue = [14, 0, 0, 0]\nclass = bird'),
#  Text(38.2701466946085, 61.608000000000004, 'X[1] <= 17.204\ngini = 0.397\nsamples = 22\nvalue = [16, 0, 0, 6]\nclass = bird'),
#  Text(37.75987807201372, 54.359999999999985, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(38.78041531720328, 54.359999999999985, 'X[1] <= 17.549\ngini = 0.32\nsamples = 20\nvalue = [16, 0, 0, 4]\nclass = bird'),
#  Text(38.2701466946085, 47.111999999999995, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = bird'),
#  Text(39.29068393979806, 47.111999999999995, 'X[0] <= 0.473\ngini = 0.444\nsamples = 12\nvalue = [8, 0, 0, 4]\nclass = bird'),
#  Text(38.78041531720328, 39.864000000000004, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = bird'),
#  Text(39.800952562392844, 39.864000000000004, 'X[0] <= 0.489\ngini = 0.5\nsamples = 8\nvalue = [4, 0, 0, 4]\nclass = bird'),
#  Text(39.29068393979806, 32.615999999999985, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(40.31122118498762, 32.615999999999985, 'X[1] <= 17.562\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2]\nclass = bird'),
#  Text(39.800952562392844, 25.367999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(40.8214898075824, 25.367999999999995, 'X[1] <= 17.853\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = bird'),
#  Text(40.31122118498762, 18.120000000000005, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(41.33175843017718, 18.120000000000005, 'X[1] <= 17.95\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(40.8214898075824, 10.871999999999986, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(41.84202705277196, 10.871999999999986, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(37.24960944941894, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(38.78041531720328, 90.6, 'X[0] <= 0.604\ngini = 0.064\nsamples = 30\nvalue = [29, 0, 0, 1]\nclass = bird'),
#  Text(38.2701466946085, 83.352, 'gini = 0.0\nsamples = 27\nvalue = [27, 0, 0, 0]\nclass = bird'),
#  Text(39.29068393979806, 83.352, 'X[0] <= 0.607\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(38.78041531720328, 76.10399999999998, 'X[1] <= 16.578\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(38.2701466946085, 68.856, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(39.29068393979806, 68.856, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(39.800952562392844, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(35.208534959039824, 112.344, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(39.800952562392844, 119.592, 'X[1] <= 20.37\ngini = 0.089\nsamples = 43\nvalue = [41, 0, 0, 2]\nclass = bird'),
#  Text(39.29068393979806, 112.344, 'gini = 0.0\nsamples = 33\nvalue = [33, 0, 0, 0]\nclass = bird'),
#  Text(40.31122118498762, 112.344, 'X[1] <= 20.55\ngini = 0.32\nsamples = 10\nvalue = [8, 0, 0, 2]\nclass = bird'),
#  Text(39.800952562392844, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(40.8214898075824, 105.09599999999999, 'X[1] <= 20.76\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 0, 1]\nclass = bird'),
#  Text(40.31122118498762, 97.848, 'X[1] <= 20.707\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]\nclass = bird'),
#  Text(39.800952562392844, 90.6, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(40.8214898075824, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(41.33175843017718, 97.848, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = bird'),
#  Text(41.33175843017718, 126.83999999999999, 'X[1] <= 15.55\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(40.8214898075824, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(41.84202705277196, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(35.97393789293199, 155.832, 'gini = 0.0\nsamples = 130\nvalue = [130, 0, 0, 0]\nclass = bird'),
#  Text(49.017679558011054, 170.328, 'X[0] <= 0.591\ngini = 0.369\nsamples = 176\nvalue = [133, 0, 0, 43]\nclass = bird'),
#  Text(47.19984759001715, 163.07999999999998, 'X[1] <= 27.832\ngini = 0.489\nsamples = 33\nvalue = [14, 0, 0, 19]\nclass = mammal'),
#  Text(46.68957896742237, 155.832, 'X[1] <= 25.43\ngini = 0.5\nsamples = 28\nvalue = [14, 0, 0, 14]\nclass = bird'),
#  Text(46.17931034482759, 148.584, 'X[1] <= 24.275\ngini = 0.493\nsamples = 25\nvalue = [11, 0, 0, 14]\nclass = mammal'),
#  Text(45.66904172223281, 141.336, 'X[1] <= 23.26\ngini = 0.499\nsamples = 21\nvalue = [11, 0, 0, 10]\nclass = bird'),
#  Text(44.393370165745864, 134.088, 'X[1] <= 21.863\ngini = 0.459\nsamples = 14\nvalue = [5, 0, 0, 9]\nclass = mammal'),
#  Text(43.3728329205563, 126.83999999999999, 'X[1] <= 21.682\ngini = 0.49\nsamples = 7\nvalue = [4, 0, 0, 3]\nclass = bird'),
#  Text(42.86256429796152, 119.592, 'X[1] <= 21.589\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]\nclass = mammal'),
#  Text(42.35229567536674, 112.344, 'X[1] <= 21.34\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(41.84202705277196, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(42.86256429796152, 105.09599999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(43.3728329205563, 112.344, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(43.88310154315108, 119.592, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(45.41390741093542, 126.83999999999999, 'X[0] <= 0.553\ngini = 0.245\nsamples = 7\nvalue = [1, 0, 0, 6]\nclass = mammal'),
#  Text(44.90363878834064, 119.592, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = mammal'),
#  Text(45.9241760335302, 119.592, 'X[0] <= 0.578\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]\nclass = mammal'),
#  Text(45.41390741093542, 112.344, 'X[1] <= 22.545\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(44.90363878834064, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(45.9241760335302, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(46.43444465612498, 112.344, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(46.94471327871976, 134.088, 'X[0] <= 0.585\ngini = 0.245\nsamples = 7\nvalue = [6, 0, 0, 1]\nclass = bird'),
#  Text(46.43444465612498, 126.83999999999999, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = bird'),
#  Text(47.45498190131454, 126.83999999999999, 'X[1] <= 23.925\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(46.94471327871976, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(47.96525052390932, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(46.68957896742237, 141.336, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = mammal'),
#  Text(47.19984759001715, 148.584, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(47.71011621261193, 155.832, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]\nclass = mammal'),
#  Text(50.83551152600496, 163.07999999999998, 'X[1] <= 21.708\ngini = 0.279\nsamples = 143\nvalue = [119, 0, 0, 24]\nclass = bird'),
#  Text(49.04957134692323, 155.832, 'X[0] <= 0.696\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]\nclass = mammal'),
#  Text(48.53930272432845, 148.584, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(49.55983996951801, 148.584, 'X[0] <= 0.705\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(49.04957134692323, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(50.07010859211279, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(52.62145170508669, 155.832, 'X[1] <= 23.158\ngini = 0.265\nsamples = 140\nvalue = [118, 0, 0, 22]\nclass = bird'),
#  Text(51.600914459897126, 148.584, 'X[0] <= 0.648\ngini = 0.057\nsamples = 34\nvalue = [33, 0, 0, 1]\nclass = bird'),
#  Text(51.09064583730235, 141.336, 'X[0] <= 0.642\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 0, 1]\nclass = bird'),
#  Text(50.58037721470757, 134.088, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = bird'),
#  Text(51.600914459897126, 134.088, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(52.111183082491905, 141.336, 'gini = 0.0\nsamples = 25\nvalue = [25, 0, 0, 0]\nclass = bird'),
#  Text(53.64198895027625, 148.584, 'X[0] <= 0.739\ngini = 0.318\nsamples = 106\nvalue = [85, 0, 0, 21]\nclass = bird'),
#  Text(53.13172032768147, 141.336, 'X[1] <= 23.205\ngini = 0.308\nsamples = 105\nvalue = [85, 0, 0, 20]\nclass = bird'),
#  Text(52.62145170508669, 134.088, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(53.64198895027625, 134.088, 'X[1] <= 26.106\ngini = 0.299\nsamples = 104\nvalue = [85, 0, 0, 19]\nclass = bird'),
#  Text(49.496056391693664, 126.83999999999999, 'X[1] <= 26.09\ngini = 0.361\nsamples = 55\nvalue = [42, 0, 0, 13]\nclass = bird'),
#  Text(48.98578776909888, 119.592, 'X[1] <= 23.375\ngini = 0.329\nsamples = 53\nvalue = [42, 0, 0, 11]\nclass = bird'),
#  Text(48.4755191465041, 112.344, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = bird'),
#  Text(49.496056391693664, 112.344, 'X[1] <= 23.422\ngini = 0.359\nsamples = 47\nvalue = [36, 0, 0, 11]\nclass = bird'),
#  Text(48.98578776909888, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(50.00632501428844, 105.09599999999999, 'X[0] <= 0.7\ngini = 0.34\nsamples = 46\nvalue = [36, 0, 0, 10]\nclass = bird'),
#  Text(47.32741474566585, 97.848, 'X[0] <= 0.66\ngini = 0.413\nsamples = 24\nvalue = [17, 0, 0, 7]\nclass = bird'),
#  Text(45.541474566584114, 90.6, 'X[1] <= 25.49\ngini = 0.18\nsamples = 10\nvalue = [9, 0, 0, 1]\nclass = bird'),
#  Text(45.031205943989335, 83.352, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = bird'),
#  Text(46.05174318917889, 83.352, 'X[1] <= 25.65\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]\nclass = bird'),
#  Text(45.541474566584114, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(46.56201181177367, 76.10399999999998, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(49.113354924747576, 90.6, 'X[1] <= 24.092\ngini = 0.49\nsamples = 14\nvalue = [8, 0, 0, 6]\nclass = bird'),
#  Text(48.09281767955802, 83.352, 'X[0] <= 0.694\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = mammal'),
#  Text(47.58254905696324, 76.10399999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = mammal'),
#  Text(48.603086302152796, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(50.133892169937134, 83.352, 'X[1] <= 24.995\ngini = 0.42\nsamples = 10\nvalue = [7, 0, 0, 3]\nclass = bird'),
#  Text(49.623623547342355, 76.10399999999998, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = bird'),
#  Text(50.64416079253191, 76.10399999999998, 'X[1] <= 25.663\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 0, 3]\nclass = bird'),
#  Text(50.133892169937134, 68.856, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(51.15442941512669, 68.856, 'X[1] <= 25.903\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]\nclass = bird'),
#  Text(50.64416079253191, 61.608000000000004, 'X[1] <= 25.863\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(50.133892169937134, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(51.15442941512669, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(51.66469803772148, 61.608000000000004, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(52.68523528291104, 97.848, 'X[0] <= 0.716\ngini = 0.236\nsamples = 22\nvalue = [19, 0, 0, 3]\nclass = bird'),
#  Text(51.66469803772148, 90.6, 'X[1] <= 24.706\ngini = 0.117\nsamples = 16\nvalue = [15, 0, 0, 1]\nclass = bird'),
#  Text(51.15442941512669, 83.352, 'gini = 0.0\nsamples = 11\nvalue = [11, 0, 0, 0]\nclass = bird'),
#  Text(52.17496666031626, 83.352, 'X[1] <= 25.03\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = bird'),
#  Text(51.66469803772148, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(52.68523528291104, 76.10399999999998, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = bird'),
#  Text(53.705772528100596, 90.6, 'X[0] <= 0.72\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2]\nclass = bird'),
#  Text(53.19550390550582, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(54.216041150695375, 83.352, 'X[1] <= 24.573\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = bird'),
#  Text(53.705772528100596, 76.10399999999998, 'X[0] <= 0.725\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(53.19550390550582, 68.856, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(54.216041150695375, 68.856, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(54.726309773290154, 76.10399999999998, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(50.00632501428844, 119.592, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(57.78792150885884, 126.83999999999999, 'X[1] <= 28.177\ngini = 0.215\nsamples = 49\nvalue = [43, 0, 0, 6]\nclass = bird'),
#  Text(56.76738426366928, 119.592, 'X[0] <= 0.711\ngini = 0.124\nsamples = 30\nvalue = [28, 0, 0, 2]\nclass = bird'),
#  Text(56.2571156410745, 112.344, 'X[0] <= 0.707\ngini = 0.208\nsamples = 17\nvalue = [15, 0, 0, 2]\nclass = bird'),
#  Text(55.74684701847971, 105.09599999999999, 'X[1] <= 26.607\ngini = 0.117\nsamples = 16\nvalue = [15, 0, 0, 1]\nclass = bird'),
#  Text(55.23657839588493, 97.848, 'X[1] <= 26.58\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = bird'),
#  Text(54.726309773290154, 90.6, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = bird'),
#  Text(55.74684701847971, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(56.2571156410745, 97.848, 'gini = 0.0\nsamples = 11\nvalue = [11, 0, 0, 0]\nclass = bird'),
#  Text(56.76738426366928, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(57.27765288626406, 112.344, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0, 0]\nclass = bird'),
#  Text(58.808458754048395, 119.592, 'X[1] <= 28.342\ngini = 0.332\nsamples = 19\nvalue = [15, 0, 0, 4]\nclass = bird'),
#  Text(58.298190131453616, 112.344, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(59.318727376643174, 112.344, 'X[0] <= 0.735\ngini = 0.208\nsamples = 17\nvalue = [15, 0, 0, 2]\nclass = bird'),
#  Text(58.808458754048395, 105.09599999999999, 'X[0] <= 0.65\ngini = 0.117\nsamples = 16\nvalue = [15, 0, 0, 1]\nclass = bird'),
#  Text(58.298190131453616, 97.848, 'X[0] <= 0.613\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(57.78792150885884, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(58.808458754048395, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(59.318727376643174, 97.848, 'gini = 0.0\nsamples = 14\nvalue = [14, 0, 0, 0]\nclass = bird'),
#  Text(59.828995999237954, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(54.15225757287103, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(61.2322347113736, 177.576, 'X[1] <= 11.15\ngini = 0.043\nsamples = 546\nvalue = [534, 0, 0, 12]\nclass = bird'),
#  Text(59.573861687940564, 170.328, 'X[1] <= 8.915\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(59.063593065345785, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(60.08413031053534, 163.07999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(62.890607734806636, 170.328, 'X[0] <= 1.284\ngini = 0.04\nsamples = 544\nvalue = [533, 0, 0, 11]\nclass = bird'),
#  Text(61.10466755572491, 163.07999999999998, 'X[1] <= 23.987\ngini = 0.034\nsamples = 523\nvalue = [514, 0, 0, 9]\nclass = bird'),
#  Text(60.59439893313012, 155.832, 'gini = 0.0\nsamples = 235\nvalue = [235, 0, 0, 0]\nclass = bird'),
#  Text(61.61493617831969, 155.832, 'X[1] <= 24.065\ngini = 0.061\nsamples = 288\nvalue = [279, 0, 0, 9]\nclass = bird'),
#  Text(60.59439893313012, 148.584, 'X[0] <= 0.81\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(60.08413031053534, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(61.10466755572491, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(62.63547342350925, 148.584, 'X[0] <= 0.9\ngini = 0.054\nsamples = 286\nvalue = [278, 0, 0, 8]\nclass = bird'),
#  Text(62.12520480091447, 141.336, 'X[0] <= 0.786\ngini = 0.077\nsamples = 199\nvalue = [191, 0, 0, 8]\nclass = bird'),
#  Text(61.61493617831969, 134.088, 'gini = 0.0\nsamples = 51\nvalue = [51, 0, 0, 0]\nclass = bird'),
#  Text(62.63547342350925, 134.088, 'X[0] <= 0.787\ngini = 0.102\nsamples = 148\nvalue = [140, 0, 0, 8]\nclass = bird'),
#  Text(60.84953324442752, 126.83999999999999, 'X[1] <= 27.072\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(60.33926462183273, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(61.3598018670223, 119.592, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(64.42141360259097, 126.83999999999999, 'X[1] <= 28.993\ngini = 0.091\nsamples = 146\nvalue = [139, 0, 0, 7]\nclass = bird'),
#  Text(62.38033911221186, 119.592, 'X[1] <= 25.216\ngini = 0.055\nsamples = 107\nvalue = [104, 0, 0, 3]\nclass = bird'),
#  Text(61.3598018670223, 112.344, 'X[1] <= 25.125\ngini = 0.147\nsamples = 25\nvalue = [23, 0, 0, 2]\nclass = bird'),
#  Text(60.84953324442752, 105.09599999999999, 'X[0] <= 0.826\ngini = 0.08\nsamples = 24\nvalue = [23, 0, 0, 1]\nclass = bird'),
#  Text(60.33926462183273, 97.848, 'X[0] <= 0.821\ngini = 0.219\nsamples = 8\nvalue = [7, 0, 0, 1]\nclass = bird'),
#  Text(59.828995999237954, 90.6, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = bird'),
#  Text(60.84953324442752, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(61.3598018670223, 97.848, 'gini = 0.0\nsamples = 16\nvalue = [16, 0, 0, 0]\nclass = bird'),
#  Text(61.87007048961708, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(63.400876357401415, 112.344, 'X[0] <= 0.899\ngini = 0.024\nsamples = 82\nvalue = [81, 0, 0, 1]\nclass = bird'),
#  Text(62.890607734806636, 105.09599999999999, 'gini = 0.0\nsamples = 73\nvalue = [73, 0, 0, 0]\nclass = bird'),
#  Text(63.911144979996195, 105.09599999999999, 'X[1] <= 27.45\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 0, 1]\nclass = bird'),
#  Text(63.400876357401415, 97.848, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = bird'),
#  Text(64.42141360259097, 97.848, 'X[1] <= 27.625\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(63.911144979996195, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(64.93168222518575, 90.6, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(66.46248809297009, 119.592, 'X[1] <= 29.007\ngini = 0.184\nsamples = 39\nvalue = [35, 0, 0, 4]\nclass = bird'),
#  Text(65.44195084778053, 112.344, 'X[0] <= 0.89\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(64.93168222518575, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(65.95221947037531, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(67.48302533815965, 112.344, 'X[1] <= 29.602\ngini = 0.149\nsamples = 37\nvalue = [34, 0, 0, 3]\nclass = bird'),
#  Text(66.97275671556487, 105.09599999999999, 'gini = 0.0\nsamples = 11\nvalue = [11, 0, 0, 0]\nclass = bird'),
#  Text(67.99329396075444, 105.09599999999999, 'X[1] <= 29.708\ngini = 0.204\nsamples = 26\nvalue = [23, 0, 0, 3]\nclass = bird'),
#  Text(67.48302533815965, 97.848, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(68.50356258334922, 97.848, 'X[1] <= 30.095\ngini = 0.147\nsamples = 25\nvalue = [23, 0, 0, 2]\nclass = bird'),
#  Text(67.48302533815965, 90.6, 'X[1] <= 29.99\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 0, 1]\nclass = bird'),
#  Text(66.97275671556487, 83.352, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = bird'),
#  Text(67.99329396075444, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(69.52409982853878, 90.6, 'X[1] <= 31.045\ngini = 0.1\nsamples = 19\nvalue = [18, 0, 0, 1]\nclass = bird'),
#  Text(69.013831205944, 83.352, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]\nclass = bird'),
#  Text(70.03436845113356, 83.352, 'X[1] <= 31.075\ngini = 0.245\nsamples = 7\nvalue = [6, 0, 0, 1]\nclass = bird'),
#  Text(69.52409982853878, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(70.54463707372834, 76.10399999999998, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = bird'),
#  Text(63.145742046104026, 141.336, 'gini = 0.0\nsamples = 87\nvalue = [87, 0, 0, 0]\nclass = bird'),
#  Text(64.67654791388837, 163.07999999999998, 'X[0] <= 1.295\ngini = 0.172\nsamples = 21\nvalue = [19, 0, 0, 2]\nclass = bird'),
#  Text(64.16627929129359, 155.832, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(65.18681653648315, 155.832, 'X[1] <= 20.6\ngini = 0.095\nsamples = 20\nvalue = [19, 0, 0, 1]\nclass = bird'),
#  Text(64.67654791388837, 148.584, 'X[0] <= 1.35\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(64.16627929129359, 141.336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(65.18681653648315, 141.336, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(65.69708515907793, 148.584, 'gini = 0.0\nsamples = 17\nvalue = [17, 0, 0, 0]\nclass = bird'),
#  Text(161.484135445442, 192.072, 'X[0] <= 0.795\ngini = 0.32\nsamples = 2489\nvalue = [1996, 0, 15, 478]\nclass = bird'),
#  Text(73.09598018670223, 184.824, 'X[1] <= 132.625\ngini = 0.575\nsamples = 84\nvalue = [33, 0, 8, 43]\nclass = mammal'),
#  Text(72.58571156410746, 177.576, 'X[1] <= 42.8\ngini = 0.504\nsamples = 77\nvalue = [33, 0, 1, 43]\nclass = mammal'),
#  Text(70.03436845113356, 170.328, 'X[0] <= 0.694\ngini = 0.496\nsamples = 46\nvalue = [25, 0, 0, 21]\nclass = bird'),
#  Text(69.013831205944, 163.07999999999998, 'X[0] <= 0.653\ngini = 0.487\nsamples = 31\nvalue = [13, 0, 0, 18]\nclass = mammal'),
#  Text(68.50356258334922, 155.832, 'X[1] <= 33.631\ngini = 0.497\nsamples = 24\nvalue = [13, 0, 0, 11]\nclass = bird'),
#  Text(67.99329396075444, 148.584, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]\nclass = mammal'),
#  Text(69.013831205944, 148.584, 'X[0] <= 0.405\ngini = 0.401\nsamples = 18\nvalue = [13, 0, 0, 5]\nclass = bird'),
#  Text(68.50356258334922, 141.336, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(69.52409982853878, 141.336, 'X[0] <= 0.545\ngini = 0.305\nsamples = 16\nvalue = [13, 0, 0, 3]\nclass = bird'),
#  Text(69.013831205944, 134.088, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = bird'),
#  Text(70.03436845113356, 134.088, 'X[0] <= 0.615\ngini = 0.444\nsamples = 9\nvalue = [6, 0, 0, 3]\nclass = bird'),
#  Text(69.52409982853878, 126.83999999999999, 'X[0] <= 0.589\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]\nclass = mammal'),
#  Text(69.013831205944, 119.592, 'X[0] <= 0.556\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(68.50356258334922, 112.344, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(69.52409982853878, 112.344, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(70.03436845113356, 119.592, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
# ...
#  Text(148.9346542198514, 119.592, 'gini = 0.0\nsamples = 60\nvalue = [60, 0, 0, 0]\nclass = bird'),
#  Text(151.7411316441227, 126.83999999999999, 'X[0] <= 2.265\ngini = 0.238\nsamples = 58\nvalue = [50, 0, 0, 8]\nclass = bird'),
#  Text(151.23086302152794, 119.592, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = mammal'),
#  Text(152.2514002667175, 119.592, 'X[0] <= 2.334\ngini = 0.165\nsamples = 55\nvalue = [50, 0, 0, 5]\nclass = bird'),
#  Text(150.97572871023053, 112.344, 'X[0] <= 2.31\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2]\nclass = bird'),
#  Text(150.46546008763576, 105.09599999999999, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = bird'),
#  Text(151.48599733282532, 105.09599999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(153.52707182320444, 112.344, 'X[0] <= 2.429\ngini = 0.115\nsamples = 49\nvalue = [46, 0, 0, 3]\nclass = bird'),
#  Text(152.50653457801488, 105.09599999999999, 'X[1] <= 112.736\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 0, 1]\nclass = bird'),
#  Text(151.99626595542009, 97.848, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = bird'),
#  Text(153.01680320060964, 97.848, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(154.547609068394, 105.09599999999999, 'X[1] <= 108.06\ngini = 0.089\nsamples = 43\nvalue = [41, 0, 0, 2]\nclass = bird'),
#  Text(154.0373404457992, 97.848, 'X[1] <= 107.7\ngini = 0.165\nsamples = 22\nvalue = [20, 0, 0, 2]\nclass = bird'),
#  Text(153.52707182320444, 90.6, 'X[0] <= 3.765\ngini = 0.091\nsamples = 21\nvalue = [20, 0, 0, 1]\nclass = bird'),
#  Text(153.01680320060964, 83.352, 'gini = 0.0\nsamples = 15\nvalue = [15, 0, 0, 0]\nclass = bird'),
#  Text(154.0373404457992, 83.352, 'X[0] <= 3.86\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 0, 1]\nclass = bird'),
#  Text(153.52707182320444, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(154.547609068394, 76.10399999999998, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = bird'),
#  Text(154.547609068394, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(155.05787769098876, 97.848, 'gini = 0.0\nsamples = 21\nvalue = [21, 0, 0, 0]\nclass = bird'),
#  Text(174.9583539721852, 141.336, 'X[0] <= 2.222\ngini = 0.291\nsamples = 475\nvalue = [391, 0, 0, 84]\nclass = bird'),
#  Text(157.67300438178702, 134.088, 'X[1] <= 120.985\ngini = 0.38\nsamples = 102\nvalue = [76, 0, 0, 26]\nclass = bird'),
#  Text(157.16273575919223, 126.83999999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(158.1832730043818, 126.83999999999999, 'X[1] <= 133.9\ngini = 0.365\nsamples = 100\nvalue = [76, 0, 0, 24]\nclass = bird'),
#  Text(155.56814631358355, 119.592, 'X[1] <= 129.55\ngini = 0.1\nsamples = 19\nvalue = [18, 0, 0, 1]\nclass = bird'),
#  Text(155.05787769098876, 112.344, 'gini = 0.0\nsamples = 11\nvalue = [11, 0, 0, 0]\nclass = bird'),
#  Text(156.07841493617835, 112.344, 'X[1] <= 130.85\ngini = 0.219\nsamples = 8\nvalue = [7, 0, 0, 1]\nclass = bird'),
#  Text(155.56814631358355, 105.09599999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(156.5886835587731, 105.09599999999999, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = bird'),
#  Text(160.79839969518005, 119.592, 'X[1] <= 143.019\ngini = 0.407\nsamples = 81\nvalue = [58, 0, 0, 23]\nclass = bird'),
#  Text(158.11948942655746, 112.344, 'X[0] <= 1.734\ngini = 0.463\nsamples = 11\nvalue = [4, 0, 0, 7]\nclass = mammal'),
#  Text(157.60922080396267, 105.09599999999999, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = mammal'),
#  Text(158.62975804915223, 105.09599999999999, 'X[0] <= 1.83\ngini = 0.49\nsamples = 7\nvalue = [4, 0, 0, 3]\nclass = bird'),
#  Text(158.11948942655746, 97.848, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(159.14002667174702, 97.848, 'X[0] <= 1.959\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = mammal'),
#  Text(158.62975804915223, 90.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(159.6502952943418, 90.6, 'X[1] <= 140.373\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(159.14002667174702, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(160.16056391693658, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(163.47730996380264, 112.344, 'X[0] <= 1.875\ngini = 0.353\nsamples = 70\nvalue = [54, 0, 0, 16]\nclass = bird'),
#  Text(161.6913697847209, 105.09599999999999, 'X[0] <= 1.645\ngini = 0.191\nsamples = 28\nvalue = [25, 0, 0, 3]\nclass = bird'),
#  Text(161.18110116212614, 97.848, 'X[0] <= 1.505\ngini = 0.397\nsamples = 11\nvalue = [8, 0, 0, 3]\nclass = bird'),
#  Text(160.67083253953135, 90.6, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = bird'),
#  Text(161.6913697847209, 90.6, 'X[1] <= 198.5\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 0, 3]\nclass = bird'),
#  Text(161.18110116212614, 83.352, 'X[0] <= 1.632\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]\nclass = bird'),
#  Text(160.67083253953135, 76.10399999999998, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(161.6913697847209, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(162.2016384073157, 83.352, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(162.2016384073157, 97.848, 'gini = 0.0\nsamples = 17\nvalue = [17, 0, 0, 0]\nclass = bird'),
#  Text(165.26325014288437, 105.09599999999999, 'X[0] <= 1.905\ngini = 0.427\nsamples = 42\nvalue = [29, 0, 0, 13]\nclass = bird'),
#  Text(164.24271289769482, 97.848, 'X[1] <= 277.15\ngini = 0.49\nsamples = 7\nvalue = [3, 0, 0, 4]\nclass = mammal'),
#  Text(163.73244427510002, 90.6, 'X[1] <= 184.5\ngini = 0.444\nsamples = 6\nvalue = [2, 0, 0, 4]\nclass = mammal'),
#  Text(163.22217565250526, 83.352, 'X[1] <= 149.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(162.71190702991046, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(163.73244427510002, 76.10399999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(164.24271289769482, 83.352, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]\nclass = mammal'),
#  Text(164.7529815202896, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(166.28378738807393, 97.848, 'X[1] <= 146.04\ngini = 0.382\nsamples = 35\nvalue = [26, 0, 0, 9]\nclass = bird'),
#  Text(165.77351876547917, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(166.79405601066873, 90.6, 'X[1] <= 175.734\ngini = 0.36\nsamples = 34\nvalue = [26, 0, 0, 8]\nclass = bird'),
#  Text(166.28378738807393, 83.352, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = bird'),
#  Text(167.3043246332635, 83.352, 'X[0] <= 2.139\ngini = 0.417\nsamples = 27\nvalue = [19, 0, 0, 8]\nclass = bird'),
#  Text(166.02865307677655, 76.10399999999998, 'X[1] <= 182.42\ngini = 0.308\nsamples = 21\nvalue = [17, 0, 0, 4]\nclass = bird'),
#  Text(165.008115831587, 68.856, 'X[0] <= 2.059\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]\nclass = mammal'),
#  Text(164.4978472089922, 61.608000000000004, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(165.51838445418176, 61.608000000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(167.0491903219661, 68.856, 'X[0] <= 2.036\ngini = 0.198\nsamples = 18\nvalue = [16, 0, 0, 2]\nclass = bird'),
#  Text(166.53892169937131, 61.608000000000004, 'gini = 0.0\nsamples = 10\nvalue = [10, 0, 0, 0]\nclass = bird'),
#  Text(167.55945894456087, 61.608000000000004, 'X[1] <= 258.0\ngini = 0.375\nsamples = 8\nvalue = [6, 0, 0, 2]\nclass = bird'),
#  Text(167.0491903219661, 54.359999999999985, 'X[1] <= 196.152\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 0, 2]\nclass = bird'),
#  Text(166.53892169937131, 47.111999999999995, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(167.55945894456087, 47.111999999999995, 'X[0] <= 2.095\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2]\nclass = mammal'),
#  Text(167.0491903219661, 39.864000000000004, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(168.06972756715567, 39.864000000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(168.06972756715567, 54.359999999999985, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(168.57999618975043, 76.10399999999998, 'X[1] <= 196.55\ngini = 0.444\nsamples = 6\nvalue = [2, 0, 0, 4]\nclass = mammal'),
#  Text(168.06972756715567, 68.856, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(169.09026481234523, 68.856, 'X[1] <= 299.75\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 0, 4]\nclass = mammal'),
#  Text(168.57999618975043, 61.608000000000004, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]\nclass = mammal'),
#  Text(169.60053343494002, 61.608000000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(192.24370356258336, 134.088, 'X[0] <= 3.969\ngini = 0.263\nsamples = 373\nvalue = [315, 0, 0, 58]\nclass = bird'),
#  Text(181.11346923223473, 126.83999999999999, 'X[1] <= 193.674\ngini = 0.207\nsamples = 264\nvalue = [233, 0, 0, 31]\nclass = bird'),
#  Text(175.02213755000955, 119.592, 'X[1] <= 173.675\ngini = 0.288\nsamples = 126\nvalue = [104, 0, 0, 22]\nclass = bird'),
#  Text(170.36593636883217, 112.344, 'X[1] <= 125.425\ngini = 0.209\nsamples = 93\nvalue = [82, 0, 0, 11]\nclass = bird'),
#  Text(167.81459325585828, 105.09599999999999, 'X[1] <= 120.75\ngini = 0.49\nsamples = 7\nvalue = [4, 0, 0, 3]\nclass = bird'),
#  Text(167.3043246332635, 97.848, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(168.32486187845305, 97.848, 'X[1] <= 122.19\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 0, 3]\nclass = mammal'),
#  Text(167.81459325585828, 90.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(168.83513050104784, 90.6, 'X[1] <= 124.613\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  Text(168.32486187845305, 83.352, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(169.3453991236426, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(172.91727948180608, 105.09599999999999, 'X[0] <= 3.415\ngini = 0.169\nsamples = 86\nvalue = [78, 0, 0, 8]\nclass = bird'),
#  Text(172.40701085921128, 97.848, 'X[0] <= 3.374\ngini = 0.26\nsamples = 52\nvalue = [44, 0, 0, 8]\nclass = bird'),
#  Text(171.89674223661652, 90.6, 'X[1] <= 130.415\ngini = 0.237\nsamples = 51\nvalue = [44, 0, 0, 7]\nclass = bird'),
#  Text(170.36593636883217, 83.352, 'X[0] <= 2.453\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2]\nclass = bird'),
#  Text(169.8556677462374, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(170.87620499142696, 76.10399999999998, 'X[1] <= 129.965\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 1]\nclass = bird'),
#  Text(170.36593636883217, 68.856, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = bird'),
#  Text(171.38647361402172, 68.856, 'X[0] <= 2.56\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(170.87620499142696, 61.608000000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(171.89674223661652, 61.608000000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(173.42754810440084, 83.352, 'X[1] <= 146.85\ngini = 0.198\nsamples = 45\nvalue = [40, 0, 0, 5]\nclass = bird'),
#  Text(172.91727948180608, 76.10399999999998, 'gini = 0.0\nsamples = 19\nvalue = [19, 0, 0, 0]\nclass = bird'),
#  Text(173.93781672699564, 76.10399999999998, 'X[1] <= 147.6\ngini = 0.311\nsamples = 26\nvalue = [21, 0, 0, 5]\nclass = bird'),
#  Text(173.42754810440084, 68.856, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(174.44808534959043, 68.856, 'X[0] <= 2.96\ngini = 0.269\nsamples = 25\nvalue = [21, 0, 0, 4]\nclass = bird'),
#  Text(172.91727948180608, 61.608000000000004, 'X[1] <= 150.635\ngini = 0.111\nsamples = 17\nvalue = [16, 0, 0, 1]\nclass = bird'),
#  Text(172.40701085921128, 54.359999999999985, 'X[1] <= 149.1\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]\nclass = bird'),
#  Text(171.89674223661652, 47.111999999999995, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(172.91727948180608, 47.111999999999995, 'X[0] <= 2.805\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(172.40701085921128, 39.864000000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(173.42754810440084, 39.864000000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(173.42754810440084, 54.359999999999985, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0, 0]\nclass = bird'),
#  Text(175.97889121737475, 61.608000000000004, 'X[0] <= 3.225\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 0, 3]\nclass = bird'),
#  Text(175.46862259478, 54.359999999999985, 'X[0] <= 3.135\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = mammal'),
#  Text(174.9583539721852, 47.111999999999995, 'X[1] <= 163.376\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(174.44808534959043, 39.864000000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(175.46862259478, 39.864000000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(175.97889121737475, 47.111999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = mammal'),
#  Text(176.48915983996955, 54.359999999999985, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = bird'),
#  Text(172.91727948180608, 90.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(173.42754810440084, 97.848, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0, 0]\nclass = bird'),
#  Text(179.6783387311869, 112.344, 'X[0] <= 3.04\ngini = 0.444\nsamples = 33\nvalue = [22, 0, 0, 11]\nclass = bird'),
#  Text(178.01996570775387, 105.09599999999999, 'X[0] <= 2.643\ngini = 0.49\nsamples = 14\nvalue = [6, 0, 0, 8]\nclass = mammal'),
#  Text(177.5096970851591, 97.848, 'X[1] <= 187.725\ngini = 0.444\nsamples = 9\nvalue = [6, 0, 0, 3]\nclass = bird'),
#  Text(176.9994284625643, 90.6, 'X[1] <= 185.723\ngini = 0.49\nsamples = 7\nvalue = [4, 0, 0, 3]\nclass = bird'),
#  Text(176.48915983996955, 83.352, 'X[0] <= 2.305\ngini = 0.444\nsamples = 6\nvalue = [4, 0, 0, 2]\nclass = bird'),
#  Text(175.97889121737475, 76.10399999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(176.9994284625643, 76.10399999999998, 'X[0] <= 2.344\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 0, 2]\nclass = bird'),
#  Text(176.48915983996955, 68.856, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(177.5096970851591, 68.856, 'X[0] <= 2.412\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 0, 1]\nclass = bird'),
#  Text(176.9994284625643, 61.608000000000004, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(178.01996570775387, 61.608000000000004, 'X[0] <= 2.451\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = bird'),
#  Text(177.5096970851591, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(178.53023433034866, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = bird'),
#  Text(177.5096970851591, 83.352, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = mammal'),
#  Text(178.01996570775387, 90.6, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = bird'),
#  Text(178.53023433034866, 97.848, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]\nclass = mammal'),
#  Text(181.33671175461996, 105.09599999999999, 'X[1] <= 192.89\ngini = 0.266\nsamples = 19\nvalue = [16, 0, 0, 3]\nclass = bird'),
#  Text(180.06104019813299, 97.848, 'X[1] <= 177.75\ngini = 0.208\nsamples = 17\nvalue = [15, 0, 0, 2]\nclass = bird'),
#  Text(179.04050295294343, 90.6, 'X[1] <= 176.905\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 1]\nclass = bird'),
#  ...]

# %% [markdown]
# ## Testing
#
# We can evaluate our decision tree on our testing data.

# %%
ypredict= clf.predict(xte)
print(ypredict)
# Out:
# [0 0 0 ... 0 0 0]

# %% [markdown]
# Calculate the accuracy of the decision tree by importing `metrics` from `sklearn` and then finding the accuracy score.

# %%
metrics.accuracy_score(yte,ypredict,normalize=True, sample_weight=None)
# Out:
# 0.823574144486692

# %% [markdown]
# ## Beautification
#
# If time permits, play around with changing the appearance of your decision tree and plotting a decision surface!

# %%
newtree= tree.export_graphviz(clf,class_names=["bird","dino","reptile","mammal"],feature_names=["Brain", "Body Mass" ],out_file=None,filled=True,rounded=True)
graph  = pydotplus.graph_from_dot_data(newtree)
colors = ('lavender', 'ivory')
edges = collections.defaultdict(list)
for edge in graph.get_edge_list():
    edges[edge.get_source()].append(int(edge.get_destination()))

for edge in edges:
    edges[edge].sort()    
    for i in range(2):
        dest = graph.get_node(str(edges[edge][i]))[0]
        dest.set_fillcolor(colors[i])

graph.write_png('bigtree.png')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.784106 to fit
# True

# %%
max1= max(var["Brain mass (g)"])
min1= min(var["Brain mass (g)"])
max2= max(var["Body mass (g)"])
min2= min(var["Body mass (g)"])

# %%
xx, yy = np.meshgrid(np.arange(0.0028, max2 + 0.05, 1000),
                         np.arange(0.58 - 0.05, max1+ 0.05,1000))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
## Plot the contour plot
cs = plt.contourf(np.log10(xx), np.log10(yy), Z, cmap=mpl.colors.ListedColormap(['r','g','b','c']))
plt.xlabel("bodymass")
plt.ylabel("brain")
plt.xlim(np.log10(0.0028), np.log10(9000.0 + 0.05))
plt.ylim(np.log10(0.58 - 0.05), np.log10(9000+ 0.05))

# label the axes


# Plot the training points
for i, color in zip(range(4), "rgbc"):
    idx = np.where(y == i)
    plt.scatter(np.log10(x[idx, 0].astype(np.float64)), np.log10(x[idx, 1].astype(np.float64)), c=color, label=["Bird", "Dino","Reptile","Mammal"][i],
                cmap=mpl.colors.ListedColormap(['r','g','b','c']), edgecolor='black', s=15)

graph.write_png('jhvgf.png')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.784106 to fit
# True

# %%
idx = np.where(y == 0)
print(np.log10(x[idx, 0].astype(np.float64)))
# Out:
# [[0.6946052  0.75058553 0.69046189 ... 0.63346846 0.59106461 0.71692107]]
